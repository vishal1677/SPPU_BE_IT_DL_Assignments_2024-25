# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPool2D,Flatten

# %%
from tensorflow.keras.datasets import cifar10

# %%
(x_train,y_train),(x_test,y_test)=cifar10.load_data()

# %%
plt.imshow(x_train[1])

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 1)
# (10000, 1)

# %%
model=Sequential([
    Conv2D(32,(3,3),input_shape=(32,32,3),activation='relu'),
    MaxPool2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    MaxPool2D((2,2)),
    Conv2D(64,(3,3),activation='relu'),
    Flatten(),
    Dense(64,activation='relu'),
    Dense(10,activation='softmax'),
])

# %%
model.compile(optimizer='adam',metrics=['accuracy'],loss=tf.keras.losses.SparseCategoricalCrossentropy)

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=10,batch_size=30,shuffle=True)
# Out:
# Epoch 1/10
# 1667/1667 ━━━━━━━━━━━━━━━━━━━━ 81s 47ms/step - accuracy: 0.2891 - loss: 2.5712 - val_accuracy: 0.4523 - val_loss: 1.5110
# Epoch 2/10
# 1667/1667 ━━━━━━━━━━━━━━━━━━━━ 86s 49ms/step - accuracy: 0.4865 - loss: 1.4232 - val_accuracy: 0.5376 - val_loss: 1.2930
# Epoch 3/10
# 1667/1667 ━━━━━━━━━━━━━━━━━━━━ 139s 48ms/step - accuracy: 0.5597 - loss: 1.2426 - val_accuracy: 0.5832 - val_loss: 1.1821
# Epoch 4/10
# 1667/1667 ━━━━━━━━━━━━━━━━━━━━ 73s 44ms/step - accuracy: 0.6067 - loss: 1.1154 - val_accuracy: 0.5970 - val_loss: 1.1727
# Epoch 5/10
# 1667/1667 ━━━━━━━━━━━━━━━━━━━━ 76s 46ms/step - accuracy: 0.6340 - loss: 1.0481 - val_accuracy: 0.6058 - val_loss: 1.1566
# Epoch 6/10
# 1667/1667 ━━━━━━━━━━━━━━━━━━━━ 75s 45ms/step - accuracy: 0.6670 - loss: 0.9558 - val_accuracy: 0.6116 - val_loss: 1.1435
# Epoch 7/10
# 1667/1667 ━━━━━━━━━━━━━━━━━━━━ 73s 44ms/step - accuracy: 0.6861 - loss: 0.8992 - val_accuracy: 0.6353 - val_loss: 1.0840
# Epoch 8/10
# ...

# %%
sns.lineplot(model.history.history)
# Out:
# <Axes: >

# %%
pred=model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step

# %%
plt.imshow(x_test[3])
plt.title(pred[3].argmax())
print(y_test[3])
# Out:
# [0]
